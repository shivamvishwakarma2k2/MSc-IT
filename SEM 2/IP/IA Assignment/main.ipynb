# %%
# Run the main.py script directly by running the below notebook cell
# This allows users to execute the main Python script without leaving the notebook.

# Note: Ensure that main.py is in the same directory as this notebook, or provide the correct relative/absolute path to the file.

# %%
run main.py
